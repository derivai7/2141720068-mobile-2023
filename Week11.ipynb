# %% [markdown]
# <a href="https://colab.research.google.com/github/derivai7/2141720068-mobile-2023/blob/main/Week11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PRAKTIKUM**

# %%
import cv2
import os
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Load image
ktp_image = cv2.imread('/content/drive/MyDrive/dataset/KTP More/ktp4.png')
cv2_imshow(ktp_image)
# Out:
# <PIL.Image.Image image mode=RGB size=493x300>

# %%
# Lokasi hasil pelat
path_plate = '/content/drive/MyDrive/dataset/KTP More/'

# Looping file di direktori
for name_file in sorted(os.listdir(path_plate)):
    src = cv2.imread(os.path.join(path_plate, name_file))

    blurred = src.copy()
    gray = blurred.copy()

    # Filtering
    for i in range(10):
        blurred = cv2.GaussianBlur(src, (5, 5), 0.5)

    # Ubah ke grayscale
    gray = cv2.cvtColor(blurred, cv2.COLOR_BGR2GRAY)

    # Image binary
    ret, bw = cv2.threshold(gray.copy(), 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    print(ret, bw.shape)
    cv2_imshow(ktp_image)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-fe93b1707abf> in <cell line: 5>()
#       5 for name_file in sorted(os.listdir(path_plate)):
#       6     src = cv2.imread(os.path.join(path_plate, name_file))
# ----> 7     blurred = src.copy()
#       8     gray = blurred.copy()
#       9
#
# AttributeError: 'NoneType' object has no attribute 'copy'

# %%
# Filtering
for i in range(10):
    blurred = cv2.GaussianBlur(src, (5, 5), 0.5)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-25-24fe3fb3b1ae> in <cell line: 2>()
#       1 # Filtering
#       2 for i in range(10):
# ----> 3     blurred = cv2.GaussianBlur(src, (5, 5), 0.5)
#
# error: OpenCV(4.8.0) /io/opencv/modules/imgproc/src/smooth.dispatch.cpp:617: error: (-215:Assertion failed) !_src.empty() in function 'GaussianBlur'

# %%
# Ubah ke grayscale
gray = cv2.cvtColor(blurred, cv2.COLOR_BGR2GRAY)

ret, bw = cv2.threshold(gray.copy(), 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
print(ret, bw.shape)
# Out:
# 108.0 (375, 500)

# %%
# Ubah ke grayscale
gray = cv2.cvtColor(blurred, cv2.COLOR_BGR2GRAY)
ret, bw = cv2.threshold(ktp_image, 0, 255, cv2.THRESH_BINARY+ cv2.THRESH_OTSU)
print(ret, bw.shape)

# Tampilkan gambar asli dan hasil deteksi tepi
f, axarr = plt.subplots(1,2,figsize=(15,5))
axarr[0].imshow(cv2.cvtColor(src, cv2.COLOR_BGR2RGB))
axarr[1].imshow(bw, cmap='gray')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-18-19a7803e5a33> in <cell line: 3>()
#       1 # Ubah ke grayscale
#       2 gray = cv2.cvtColor(blurred, cv2.COLOR_BGR2GRAY)
# ----> 3 ret, bw = cv2.threshold(ktp_image, 0, 255, cv2.THRESH_BINARY+ cv2.THRESH_OTSU)
#       4 print(ret, bw.shape)
#       5
#
# error: OpenCV(4.8.0) /io/opencv/modules/imgproc/src/thresh.cpp:1555: error: (-2:Unspecified error) in function 'double cv::threshold(cv::InputArray, cv::OutputArray, double, double, int)'
# > THRESH_OTSU mode:
# >     'src_type == CV_8UC1 || src_type == CV_16UC1'
# > where
# >     'src_type' is 16 (CV_8UC3)
